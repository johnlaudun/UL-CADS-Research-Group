# %%
1 + 2 * 2 - 3
# Out:
# 2

# %%
1 + 5 * 2 - 3
# Out:
# 8

# %%
import nltk
nltk.download('book')
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /Users/ammritolalroy/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /Users/ammritolalroy/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /Users/ammritolalroy/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/ammritolalroy/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /Users/ammritolalroy/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /Users/ammritolalroy/nltk_data...
# ...

# %%
from nltk.book import *

# The following text corpora are loaded:
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G. K. Chesterton 1908

# You can interact with these texts as shown below.

# List the available texts
texts()

# Access a specific text, e.g., Moby Dick (text1)
print(text1)

# Explore word usage, e.g., concordance for the word "whale" in Moby Dick
text1.concordance("whale")
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908
# <Text: Moby Dick by Herman Melville 1851>
# Displaying 25 of 1226 matches:
# ...

# %%
import nltk
nltk.download('book')
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /Users/ammritolalroy/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /Users/ammritolalroy/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /Users/ammritolalroy/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/ammritolalroy/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /Users/ammritolalroy/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /Users/ammritolalroy/nltk_data...
# ...

# %%
from nltk.book import *
*** Introductory Examples for the NLTK Book ***
Loading text1, ..., text9 and sent1, ..., sent9
Type the name of the text or sentence to view it.
Type: 'texts()' or 'sents()' to list the materials.
text1: Moby Dick by Herman Melville 1851
text2: Sense and Sensibility by Jane Austen 1811
text3: The Book of Genesis
text4: Inaugural Address Corpus
text5: Chat Corpus
text6: Monty Python and the Holy Grail
text7: Wall Street Journal
text8: Personals Corpus
text9: The Man Who Was Thursday by G . K . Chesterton 1908
# Out:
#   Cell In[5], line 2
#     *** Introductory Examples for the NLTK Book ***
#     ^
# SyntaxError: invalid syntax

# %%
from nltk.book import *
*** Introductory Examples for the NLTK Book ***
Loading text1, ..., text9 and sent1, ..., sent9
Type the name of the text or sentence to view it.
Type: 'texts()' or 'sents()' to list the materials.
text1: Moby Dick by Herman Melville 1851
text2: Sense and Sensibility by Jane Austen 1811
text3: The Book of Genesis
text4: Inaugural Address Corpus
text5: Chat Corpus
text6: Monty Python and the Holy Grail
text7: Wall Street Journal
text8: Personals Corpus
text9: The Man Who Was Thursday by G . K . Chesterton 1908
# Out:
#   Cell In[7], line 2
#     *** Introductory Examples for the NLTK Book ***
#     ^
# SyntaxError: invalid syntax

# %%
from nltk.book import *

# The following text corpora are loaded:
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G. K. Chesterton 1908

# You can interact with these texts as shown below.

# List the available texts
texts()

# Access a specific text, e.g., Moby Dick (text1)
print(text1)

# Explore word usage, e.g., concordance for the word "whale" in Moby Dick
text1.concordance("whale")
# Out:
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908
# <Text: Moby Dick by Herman Melville 1851>
# Displaying 25 of 1226 matches:
# s , and to teach them by what name a whale - fish is to be called in our tongue
# t which is not true ." -- HACKLUYT " WHALE . ... Sw . and Dan . HVAL . This ani
# ulted ." -- WEBSTER ' S DICTIONARY " WHALE . ... It is more immediately from th
# ISH . WAL , DUTCH . HWAL , SWEDISH . WHALE , ICELANDIC . WHALE , ENGLISH . BALE
# HWAL , SWEDISH . WHALE , ICELANDIC . WHALE , ENGLISH . BALEINE , FRENCH . BALLE
# least , take the higgledy - piggledy whale statements , however authentic , in
#  dreadful gulf of this monster ' s ( whale ' s ) mouth , are immediately lost a
# ...

# %%
text1.concordance("monstrous")
Displaying 11 of 11 matches:
ong the former , one was of a most monstrous size . ... This came towards us ,
ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
ll over with a heathenish array of monstrous clubs and spears . Some were thick
d as you gazed , and wondered what monstrous cannibal and savage could ever hav
that has survived the flood ; most monstrous and most mountainous ! That Himmal
they might scout at Moby Dick as a monstrous fable , or still worse and more de
th of Radney .'" CHAPTER 55 Of the monstrous Pictures of Whales . I shall ere l
ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
ere to enter upon those still more monstrous stories of them which are to be fo
ght have been rummaged out of this monstrous cabinet there is no telling . But
of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u
# Out:
#   Cell In[11], line 4
#     ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
#                        ^
# SyntaxError: unterminated string literal (detected at line 4)

# %%
# Import the necessary preloaded texts from NLTK
from nltk.book import *

# Perform concordance search for the word "monstrous" in text1 (Moby Dick)
text1.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
# Import the necessarry preloaded test from NLTK
from nltk.book import *
# Perform concordance search for the word "whale" in text1 (MOby DIck)
text1.concordance("whale")
# Out:
# Displaying 25 of 1226 matches:
# s , and to teach them by what name a whale - fish is to be called in our tongue
# t which is not true ." -- HACKLUYT " WHALE . ... Sw . and Dan . HVAL . This ani
# ulted ." -- WEBSTER ' S DICTIONARY " WHALE . ... It is more immediately from th
# ISH . WAL , DUTCH . HWAL , SWEDISH . WHALE , ICELANDIC . WHALE , ENGLISH . BALE
# HWAL , SWEDISH . WHALE , ICELANDIC . WHALE , ENGLISH . BALEINE , FRENCH . BALLE
# least , take the higgledy - piggledy whale statements , however authentic , in
#  dreadful gulf of this monster ' s ( whale ' s ) mouth , are immediately lost a
#  patient Job ." -- RABELAIS . " This whale ' s liver was two cartloads ." -- ST
#  Touching that monstrous bulk of the whale or ork we have received nothing cert
#  of oil will be extracted out of one whale ." -- IBID . " HISTORY OF LIFE AND D
# ise ." -- KING HENRY . " Very like a whale ." -- HAMLET . " Which to secure , n
# ...

# %%
text1.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
text2.concordance("affection")
# Out:
# Displaying 25 of 79 matches:
# , however , and , as a mark of his affection for the three girls , he left them
# t . It was very well known that no affection was ever supposed to exist between
# deration of politeness or maternal affection on the side of the former , the tw
# d the suspicion -- the hope of his affection for me may warrant , without impru
# hich forbade the indulgence of his affection . She knew that his mother neither
# rd she gave one with still greater affection . Though her late conversation wit
#  can never hope to feel or inspire affection again , and if her home be uncomfo
# m of the sense , elegance , mutual affection , and domestic comfort of the fami
# , and which recommended him to her affection beyond every thing else . His soci
# ween the parties might forward the affection of Mr . Willoughby , an equally st
#  the most pointed assurance of her affection . Elinor could not be surprised at
# ...

# %%
text1.similar("monstrous")
# Out:
# true contemptible christian abundant few part mean careful puzzled
# mystifying passing curious loving wise doleful gamesome singular
# delightfully perilous fearless

# %%
text1.similar("whale")
# Out:
# ship boat sea time captain world man deck pequod other whales air
# water head crew line thing side way body

# %%
text2.similar("monstrous")
# Out:
# very so exceedingly heartily a as good great extremely remarkably
# sweet vast amazingly

# %%
text2.common_contexts(["monstrous", "very"])
# Out:
# am_glad a_pretty a_lucky is_pretty be_glad

# %%
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "American"])

# %%
len(text3)
# Out:
# 44764

# %%
len("/Users/ammritolalroy/Downloads/Argument from Personal Experience, 1000 words.txt")
# Out:
# 80

# %%
set(text3)
# Out:
# {'both',
#  'ea',
#  '!',
#  'occasion',
#  'badne',
#  'gave',
#  'Omar',
#  'overthrew',
#  'shed',
#  'Dothan',
#  'sheddeth',
#  'Ishmael',
#  'His',
#  'defiledst',
#  'inherit',
#  'cubits',
#  'reign',
#  'soul',
#  'mistress',
#  'Sell',
#  'sepulchres',
#  'so',
#  'tents',
#  'menservants',
#  'thus',
#  'Rameses',
#  'itself',
#  'Sitnah',
#  'cut',
#  'Wilt',
#  'Should',
#  'me',
#  'drank',
#  'messenger',
#  'prison',
#  'shekels',
#  'guard',
#  'twentieth',
#  'mourning',
#  'hide',
#  'sixteen',
#  'Husham',
#  'and',
#  'victuals',
#  'Yea',
#  'harvest',
#  'avenged',
#  'Thahash',
#  'Whence',
#  'waxen',
#  'tithes',
#  'breathed',
#  'Seba',
#  'creature',
#  'possession',
#  'Uz',
#  'sin',
#  'Allonbachuth',
#  'sit',
#  'Elon',
#  'talking',
#  'cease',
#  'Onam',
#  'attained',
#  'Shall',
#  'cup',
#  'baskets',
#  'wotteth',
#  'younger',
#  'closed',
#  'falsely',
#  'are',
#  'stone',
#  'Resen',
#  'should',
#  'Gershon',
#  'overseer',
#  'sceptre',
# ...

# %%
len(set(text3))
# Out:
# 2789

# %%
set("/Users/ammritolalroy/Downloads/Argument from Personal Experience, 1000 words.txt")
# Out:
# {' ',
#  ',',
#  '.',
#  '/',
#  '0',
#  '1',
#  'A',
#  'D',
#  'E',
#  'P',
#  'U',
#  'a',
#  'c',
#  'd',
#  'e',
#  'f',
#  'g',
#  'i',
#  'l',
#  'm',
#  'n',
#  'o',
#  'p',
#  'r',
#  's',
#  't',
#  'u',
#  'w',
#  'x',
#  'y'}

# %%
len(set("/Users/ammritolalroy/Downloads/Argument from Personal Experience, 1000 words.txt"))
# Out:
# 30

# %%
len(set(text3)) / len(text3)
# Out:
# 0.06230453042623537

# %%
text3.count("smote")
# Out:
# 5

# %%
100 * text3.count('a') / len(text3)
# Out:
# 0.7640067911714771

# %%
100 * text3.count("smote") / len(text3)
# Out:
# 0.01116968992940756

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)
def percentage(count, total):
    return 100 * count / total

# %%
lexical_diversity(text3)
# Out:
# 0.06230453042623537

# %%
sent1 = ['Call', 'me', 'Ishmael', '.']

# %%
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.']

# %%
len(sent1)
# Out:
# 4

# %%
lexical_diversity(sent1)
# Out:
# 1.0

# %%
sent2
# Out:
# ['The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.']

# %%
sent3
# Out:
# ['In',
#  'the',
#  'beginning',
#  'God',
#  'created',
#  'the',
#  'heaven',
#  'and',
#  'the',
#  'earth',
#  '.']

# %%
sent1 + sent4
# Out:
# ['Call',
#  'me',
#  'Ishmael',
#  '.',
#  'Fellow',
#  '-',
#  'Citizens',
#  'of',
#  'the',
#  'Senate',
#  'and',
#  'of',
#  'the',
#  'House',
#  'of',
#  'Representatives',
#  ':']

# %%
sent1.append("some")

# %%
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.', 'some']
